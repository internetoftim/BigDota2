# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import mysql
import mysql.connector
import json
import csv

# %% [markdown]
# ### Step 1 : Begin with account_ID

# %%
acct_id = '222379837'

# %% [markdown]
# ### Step 2 : Extract MATCHES from account ID

# %%
my_url = 'https://api.opendota.com/api/players/' + acct_id + '/matches'
print(my_url)
uClient = uReq(my_url) ##http request
page_html = uClient.read()
soup_out= soup(page_html, "html.parser")
test_input = page_html
test_json = json.loads(test_input)
# Out:
# https://api.opendota.com/api/players/222379837/matches

# %%
test_json[0]
# Out:
# {'match_id': 2117451979,
#  'player_slot': 1,
#  'radiant_win': False,
#  'duration': 2969,
#  'game_mode': 22,
#  'lobby_type': 7,
#  'hero_id': 48,
#  'start_time': 1454223340,
#  'version': None,
#  'kills': 5,
#  'deaths': 9,
#  'assists': 5,
#  'skill': None,
#  'leaver_status': 1,
#  'party_size': None}

# %%
len(test_json)
# Out:
# 885

# %%
test_match_one = test_json[0]

# %%
display(test_match_one['kills'])
display(test_match_one['hero_id'])
# Out:
# 5
# 48

# %% [markdown]
# ### Step 3

# %%
for match in test_json:
    display(match['match_id'])

# %%
output_file_name = 'match_list_Guanyu.csv'
with open(output_file_name, mode='w') as output_file:
    csv_writer = csv.writer(output_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    for player_match in test_json:
        print(player_match['match_id'])    
        csv_writer.writerow([player_match['match_id']])
# Out:
# 2117451979
# 2115254453
# 2089824067
# 2089720097
# 2089640365
# 2089437104
# 2088993062
# 2078329606
# 2078195374
# 2078103397
# 2071182762
# 2071031022
# 2069533614
# 2069364288
# 2069210708
# 2068378577
# 2068260230
# 2068144070
# 2068044551
# 2065501536
# 2065371093
# 2065301904
# 2065187825
# 2063083057
# 2063021808
# 2062925834
# 2061916736
# 2061837606
# 2061728591
# 2060966978
# 2060867981
# 2060646935
# 2060482730
# 2060408807
# 2060339989
# 2060262047
# 2059548262
# 2059402001
# 2059279921
# 2059113180
# 2058133093
# 2057981028
# 2057908971
# 2057853806
# 2057805307
# 2057045250
# 2056938436
# 2056481222
# 2053780484
# 2053677040
# 2053579993
# 2047339866
# 2047229543
# 2047156146
# 2047068184
# 2046937571
# 2046845969
# 2046680364
# 2044806575
# 2044718013
# 2044628631
# 2044570517
# 2044486098
# 2044309946
# 2044168853
# 2044048934
# 2043928131
# 2043803319
# 2042977034
# 2042897256
# 2042789582
# 2038536506
# 2038444344
# 2038328493
# 2035468301
# 2035366083
# 2033169416
# 2033029374
# 2032920555
# 2032813776
# 2030256719
# 2030120268
# 2029987162
# 2025738530
# 2025664997
# 2025547958
# 2025461282
# 2023221485
# 2023125751
# 2020654804
# 2018668415
# 2018591538
# 2018510504
# 2016324367
# 2016206531
# 2016094893
# 2015998715
# 2015736631
# 2013741476
# 2013632585
# 2013491423
# 2013365073
# 2013293044
# 2013184923
# 2011694010
# 2011575465
# 2011398263
# 2011258128
# 2011135099
# ### STEP 4 LOAD the file list

# %%
import pandas as pd
input_match_list = 'match_list_Guanyu.csv'
match_list = pd.read_csv(input_match_list,header=None,names=['match_id'])

# %%
match_list.head()
# Out:
#      match_id
# 0  2117451979
# 1  2115254453
# 2  2089824067
# 3  2089720097
# 4  2089640365

# %% [markdown]
# ### STEP 5 Save a match as json file

# %%
# The part where you do what with the data

# %%
match_id
# Out:
# 'filename'

# %%
with open(match_id + '.json', mode='w') as output_file:
    csv_writer = csv.writer(output_file, delimiter=',', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow([json.dumps(test_json)])

# %% [markdown]
# ### STEP 6 Loop through all the matches

# %%
output_folder = "output_Guanyu/"
for i in range(len(match_list)):
    my_url = 'https://api.opendota.com/api/matches/' + str(match_list.iloc[i].match_id)
    print(my_url)
    uClient = uReq(my_url)
    page_html = uClient.read()
    soup_out= soup(page_html, "html.parser")
    test_input = page_html
    test_json = json.loads(test_input)
    with open(output_folder + str(match_list.iloc[i].match_id) + '.json', mode='w') as output_file:
        csv_writer = csv.writer(output_file, delimiter=',', quoting=csv.QUOTE_MINIMAL)
        csv_writer.writerow([json.dumps(test_json)])
# Out:
# https://api.opendota.com/api/matches/2117451979
# https://api.opendota.com/api/matches/2115254453
# https://api.opendota.com/api/matches/2089824067
# https://api.opendota.com/api/matches/2089720097
# https://api.opendota.com/api/matches/2089640365
# https://api.opendota.com/api/matches/2089437104
# https://api.opendota.com/api/matches/2088993062
# https://api.opendota.com/api/matches/2078329606
# https://api.opendota.com/api/matches/2078195374
# https://api.opendota.com/api/matches/2078103397
# https://api.opendota.com/api/matches/2071182762
# https://api.opendota.com/api/matches/2071031022
# https://api.opendota.com/api/matches/2069533614
# https://api.opendota.com/api/matches/2069364288
# https://api.opendota.com/api/matches/2069210708
# https://api.opendota.com/api/matches/2068378577
# https://api.opendota.com/api/matches/2068260230
# https://api.opendota.com/api/matches/2068144070
# https://api.opendota.com/api/matches/2068044551
# https://api.opendota.com/api/matches/2065501536
# https://api.opendota.com/api/matches/2065371093
# https://api.opendota.com/api/matches/2065301904
# https://api.opendota.com/api/matches/2065187825
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-c700aa2506f1> in <module>()
#       3     my_url = 'https://api.opendota.com/api/matches/' + str(match_list.iloc[i].match_id)
#       4     print(my_url)
# ----> 5     uClient = uReq(my_url)
#       6     page_html = uClient.read()
#       7     soup_out= soup(page_html, "html.parser")
#
# ~/anaconda3/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1358         def https_open(self, req):
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#    1362         https_request = AbstractHTTPHandler.do_request_
#
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
#    1319                 raise URLError(err)
# -> 1320             r = h.getresponse()
#    1321         except:
#    1322             h.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1047                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1048                   self.__class__)
# -> 1049             return self.read(nbytes, buffer)
#    1050         else:
#    1051             return super().recv_into(buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.7/ssl.py in read(self, len, buffer)
#     906         try:
#     907             if buffer is not None:
# --> 908                 return self._sslobj.read(len, buffer)
#     909             else:
#     910                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
